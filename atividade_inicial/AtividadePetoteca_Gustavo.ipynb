# %%
#importar a base de dados
import pandas as pd
estoque = pd.read_excel("LivrosCalculo.xlsx")
display(estoque)
# Out:
#    Disponível                                             Título      Código  \
# 0         Sim                                Um Curso de Cálculo    CDI1-G01
# 1         Sim                                Um Curso de Cálculo    CDI2-G01
# 2         Sim                                Um Curso de Cálculo    CDI2-G02
# 3         Sim                                Um Curso de Cálculo    CDI2-G03
# 4         Sim                                Um Curso de Cálculo    CDI2-G04
# 5         Sim                                Um Curso de Cálculo    CDI2-G05
# 6         Sim                                Um Curso de Cálculo    CDI2-G06
# 7         Não                                Um Curso de Cálculo    CDI2-G07
# 8         Sim                                Um Curso de Cálculo    CDI2-G08
# 9         Sim                                Um Curso de Cálculo    CDI3-G01
# 10        Sim                                Um Curso de Cálculo    CDI3-G02
# ...

# %%
titulo= input("Qual o título do livro?")
estoque.loc[estoque["Título"]==titulo]
# Out:
# Qual o título do livro?Um Curso de Cálculo
#    Disponível               Título    Código                 Autor(es) Volume  \
# 0         Sim  Um Curso de Cálculo  CDI1-G01  Hamilton Luiz Guidorizzi      1
# 1         Sim  Um Curso de Cálculo  CDI2-G01  Hamilton Luiz Guidorizzi      2
# 2         Sim  Um Curso de Cálculo  CDI2-G02  Hamilton Luiz Guidorizzi      2
# 3         Sim  Um Curso de Cálculo  CDI2-G03  Hamilton Luiz Guidorizzi      2
# 4         Sim  Um Curso de Cálculo  CDI2-G04  Hamilton Luiz Guidorizzi      2
# 5         Sim  Um Curso de Cálculo  CDI2-G05  Hamilton Luiz Guidorizzi      2
# 6         Sim  Um Curso de Cálculo  CDI2-G06  Hamilton Luiz Guidorizzi      2
# 7         Não  Um Curso de Cálculo  CDI2-G07  Hamilton Luiz Guidorizzi      2
# 8         Sim  Um Curso de Cálculo  CDI2-G08  Hamilton Luiz Guidorizzi      2
# 9         Sim  Um Curso de Cálculo  CDI3-G01  Hamilton Luiz Guidorizzi      3
# ...

# %%
codigo= input("Qual o Código do livro?")
estoque.loc[estoque["Código"]==codigo]
# Out:
# Qual o Código do livro?CDI1-G01
#   Disponível               Título    Código                 Autor(es) Volume  \
# 0        Sim  Um Curso de Cálculo  CDI1-G01  Hamilton Luiz Guidorizzi      1
#
#   Edição Livro, Cópia ou Anotação?  Com quem está?  E-mail  Data de emprétismo
# 0     5ª                     Cópia             NaN     NaN                 NaN
